# %%
from qiskit import QuantumCircuit, Aer, execute
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create a 3-qubit quantum circuit
qc = QuantumCircuit(3, 3)

# Encoding: |q0⟩ → |q0 q1 q2⟩
qc.cx(0, 1)
qc.cx(0, 2)

# Simulate an error (flip q1)
qc.x(1)  # Uncomment to introduce an error

# Syndrome measurement (parity check)
qc.cx(0, 1)
qc.cx(0, 2)
qc.measure([1, 2], [1, 2])  # Measure parity qubits

# Correction: Apply X on q0 if error detected
qc.x(0).c_if(qc.cregs[0], 1)  # Apply correction if error detected

# Final measurement
qc.measure(0, 0)

# Simulate execution
simulator = Aer.get_backend('qasm_simulator')
result = execute(qc, simulator, shots=1024).result()
counts = result.get_counts()

# Show results
print(counts)
qc.draw(output='mpl')
plt.show()
plot_histogram(counts)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from qiskit import QuantumCircuit, Aer, execute
#       2 from qiskit.visualization import plot_histogram
#       3 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'Aer' from 'qiskit' (/opt/anaconda3/envs/IITM-DA6300/lib/python3.10/site-packages/qiskit/__init__.py)
